# %%
import pandas as pd

dfa = pd.read_csv("csv_1.csv", encoding="ISO-8859-1")
print(list(dfa.columns))
# Out:
# ['1', 'Eldon Base for stackable storage shelf, platinum', 'Muhammed MacIntyre', '3', '-213.25', '38.94', '35', 'Nunavut', 'Storage & Organization', '0.8']

# %%
dfa
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380      Clay Rozendal
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
dfa = pd.read_csv("csv_1.csv", encoding="ISO-8859-1", header=None)
dfa
# Out:
#     0                                                  1                   2  \
# 0   1   Eldon Base for stackable storage shelf, platinum  Muhammed MacIntyre
# 1   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Barry French
# 2   3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl        Barry French
# 3   4                                               R380       Clay Rozendal
# 4   5                           Holmes HEPA Air Purifier      Carlos Soltero
# 5   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs      Carlos Soltero
# 6   7  Angle-D Binders with Locking Rings, Label Holders        Carl Jackson
# 7   8            SAFCO Mobile Desk Side File, Wire Frame        Carl Jackson
# 8   9              SAFCO Commercial Wire Shelving, Black      Monica Federle
# 9  10                                          Xerox 198     Dorothy Badders
#
#      3        4       5      6        7                               8     9
# ...

# %%
dfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       10 non-null     int64
#  1   1       10 non-null     object
#  2   2       10 non-null     object
#  3   3       10 non-null     int64
#  4   4       10 non-null     float64
#  5   5       10 non-null     float64
#  6   6       10 non-null     float64
#  7   7       10 non-null     object
#  8   8       10 non-null     object
#  9   9       8 non-null      float64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 928.0+ bytes

# %%
dfa[4].max()
# Out:
# 1198.97

# %%
dfa[4].mean()
# Out:
# 67.76500000000001

# %%
dfa.describe()
# Out:
#               0           3            4          5          6         9
# count  10.00000   10.000000    10.000000   10.00000  10.000000  8.000000
# mean    5.50000  464.900000    67.765000   67.33800  17.816000  0.497500
# std     3.02765  210.501227   494.827167   81.30742  21.486285  0.151445
# min     1.00000    3.000000  -695.260000    4.98000   2.990000  0.370000
# 25%     3.25000  340.500000  -173.447500    7.64750   5.197500  0.380000
# 50%     5.50000  515.000000    17.685000   30.36000   6.970000  0.445000
# 75%     7.75000  613.000000   107.452500  114.29500  28.332500  0.580000
# max    10.00000  678.000000  1198.970000  208.16000  68.020000  0.800000
